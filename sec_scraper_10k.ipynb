# %%
import pandas as pd
import numpy as np
import os
import re
import requests
import requests_random_user_agent
from bs4 import BeautifulSoup
import preprocess_data
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/codevardhan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codevardhan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/codevardhan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Scraping

# %%
amazon_cik = '0001018724'

# %%
rss_url = f'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={amazon_cik}&type=10-k&start=0&count=10000&owner=exclude&output=atom'
sec_data = requests.get(rss_url).text
feed = BeautifulSoup(sec_data.encode('ascii'), features="xml").feed

data = []

for entry in feed.find_all('entry', recursive=False):    
    data.append(
        (
            entry.content.find('filing-href').getText(),
            entry.content.find('filing-type').getText(),
            entry.content.find('filing-date').getText()
        )
    )

# %%
filings = dict()

for url, ftype, fdate in data:
    if ftype == '10-K':
        rurl = url.replace('-index.htm', '.txt')
        filings[fdate] = requests.get(rurl).text

# %%
df = pd.DataFrame([filings])
df.index = ['filing_data']
df.head()
# Out:
#                                                     2022-02-04  \
# filing_data  <SEC-DOCUMENT>0001018724-22-000005.txt : 20220...
#
#                                                     2021-02-03  \
# filing_data  <SEC-DOCUMENT>0001018724-21-000004.txt : 20210...
#
#                                                     2020-01-31  \
# filing_data  <SEC-DOCUMENT>0001018724-20-000004.txt : 20200...
#
#                                                     2019-02-01  \
# filing_data  <SEC-DOCUMENT>0001018724-19-000004.txt : 20190...
#
#                                                     2018-02-02  \
# filing_data  <SEC-DOCUMENT>0001018724-18-000005.txt : 20180...
#
#                                                     2017-02-10  \
# filing_data  <SEC-DOCUMENT>0001018724-17-000011.txt : 20170...
#
#                                                     2016-01-29  \
# filing_data  <SEC-DOCUMENT>0001018724-16-000172.txt : 20160...
#
#                                                     2015-01-30  \
# filing_data  <SEC-DOCUMENT>0001018724-15-000006.txt : 20150...
#
#                                                     2014-01-31  \
# filing_data  <SEC-DOCUMENT>0001018724-14-000006.txt : 20140...
#
#                                                     2013-01-30  ...  \
# filing_data  <SEC-DOCUMENT>0001193125-13-028520.txt : 20130...  ...
#
#                                                     2010-01-29  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
#
#                                                     2009-01-30  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
#
#                                                     2008-02-11  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
#
#                                                     2007-02-16  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
#
#                                                     2006-02-17  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
#
#                                                     2005-03-11  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
#
#                                                     2004-02-25  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
#
#                                                     2003-02-19  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
#
#                                                     2000-03-29  \
# filing_data  <?xml version="1.0" encoding="UTF-8"?>\n<Error...
#
#                                                     1999-03-05
# filing_data  <?xml version="1.0" encoding="UTF-8"?>\n<Error...
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Cleaning

# %%
documents = dict()

start = re.compile(r'<DOCUMENT>')
end = re.compile(r'</DOCUMENT>')   

for key, value in filings.items():
    tmp = []

    start_idxs = [x.end() for x in start.finditer(value)]
    end_idxs = [x.start() for x in end.finditer(value)]

    for idx1, idx2 in zip(start_idxs, end_idxs):
        tmp.append(value[idx1:idx2])
    
    documents[key] = tmp

# %%
df2 = pd.DataFrame([documents])
df2.index = ['documents']

df3 = pd.concat([df, df2])
df3.head()
# Out:
#                                                     2022-02-04  \
# filing_data  <SEC-DOCUMENT>0001018724-22-000005.txt : 20220...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-202...
#
#                                                     2021-02-03  \
# filing_data  <SEC-DOCUMENT>0001018724-21-000004.txt : 20210...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-202...
#
#                                                     2020-01-31  \
# filing_data  <SEC-DOCUMENT>0001018724-20-000004.txt : 20200...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
#
#                                                     2019-02-01  \
# filing_data  <SEC-DOCUMENT>0001018724-19-000004.txt : 20190...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
#
#                                                     2018-02-02  \
# filing_data  <SEC-DOCUMENT>0001018724-18-000005.txt : 20180...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
#
#                                                     2017-02-10  \
# filing_data  <SEC-DOCUMENT>0001018724-17-000011.txt : 20170...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
#
#                                                     2016-01-29  \
# filing_data  <SEC-DOCUMENT>0001018724-16-000172.txt : 20160...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
#
#                                                     2015-01-30  \
# filing_data  <SEC-DOCUMENT>0001018724-15-000006.txt : 20150...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
#
#                                                     2014-01-31  \
# filing_data  <SEC-DOCUMENT>0001018724-14-000006.txt : 20140...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
#
#                                                     2013-01-30  ...  \
# filing_data  <SEC-DOCUMENT>0001193125-13-028520.txt : 20130...  ...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d445434d...  ...
#
#                                                     2010-01-29  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
#
#                                                     2009-01-30  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
#
#                                                     2008-02-11  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
#
#                                                     2007-02-16  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
#
#                                                     2006-02-17  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
#
#                                                     2005-03-11  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
#
#                                                     2004-02-25  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
#
#                                                     2003-02-19  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>v87419or...
#
#                                                     2000-03-29  \
# filing_data  <?xml version="1.0" encoding="UTF-8"?>\n<Error...
# documents                                                   []
#
#                                                     1999-03-05
# filing_data  <?xml version="1.0" encoding="UTF-8"?>\n<Error...
# documents                                                   []
#
# [2 rows x 22 columns]

# %%
docs_10k = dict()

retype = re.compile(r'<TYPE>')

for key, value in documents.items():
    for idx, v in enumerate(value):
        start_idx = [x.end() for x in retype.finditer(v)][0]

        if v[start_idx:].split("\n")[0] == "10-K":
            docs_10k[key] = v

# %%
df2 = pd.DataFrame([docs_10k])
df2.index = ['docs_10k']

df4 = pd.concat([df3, df2])
df4.head()
# Out:
#                                                     2022-02-04  \
# filing_data  <SEC-DOCUMENT>0001018724-22-000005.txt : 20220...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-202...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2021...
#
#                                                     2021-02-03  \
# filing_data  <SEC-DOCUMENT>0001018724-21-000004.txt : 20210...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-202...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2020...
#
#                                                     2020-01-31  \
# filing_data  <SEC-DOCUMENT>0001018724-20-000004.txt : 20200...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2019...
#
#                                                     2019-02-01  \
# filing_data  <SEC-DOCUMENT>0001018724-19-000004.txt : 20190...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2018...
#
#                                                     2018-02-02  \
# filing_data  <SEC-DOCUMENT>0001018724-18-000005.txt : 20180...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2017...
#
#                                                     2017-02-10  \
# filing_data  <SEC-DOCUMENT>0001018724-17-000011.txt : 20170...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2016...
#
#                                                     2016-01-29  \
# filing_data  <SEC-DOCUMENT>0001018724-16-000172.txt : 20160...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2015...
#
#                                                     2015-01-30  \
# filing_data  <SEC-DOCUMENT>0001018724-15-000006.txt : 20150...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2014...
#
#                                                     2014-01-31  \
# filing_data  <SEC-DOCUMENT>0001018724-14-000006.txt : 20140...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2013...
#
#                                                     2013-01-30  ...  \
# filing_data  <SEC-DOCUMENT>0001193125-13-028520.txt : 20130...  ...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d445434d...  ...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d445434d1...  ...
#
#                                                     2010-01-29  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
#
#                                                     2009-01-30  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
#
#                                                     2008-02-11  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
#
#                                                     2007-02-16  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
#
#                                                     2006-02-17  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
#
#                                                     2005-03-11  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
#
#                                                     2004-02-25  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
#
#                                                     2003-02-19  \
# filing_data  -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents    [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>v87419or...
# docs_10k     \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>v87419ore...
#
#                                                     2000-03-29  \
# filing_data  <?xml version="1.0" encoding="UTF-8"?>\n<Error...
# documents                                                   []
# docs_10k                                                   NaN
#
#                                                     1999-03-05
# filing_data  <?xml version="1.0" encoding="UTF-8"?>\n<Error...
# documents                                                   []
# docs_10k                                                   NaN
#
# [3 rows x 22 columns]

# %%
docs_10k_clean = dict()

for key, data in docs_10k.items():
    x = data.lower()
    x = BeautifulSoup(x, 'html.parser').get_text()
    docs_10k_clean[key] = x

df2 = pd.DataFrame([docs_10k_clean])
df2.index = ['docs_10k_clean']

df5 = pd.concat([df4, df2])
df5.head()
# Out:
#                                                        2022-02-04  \
# filing_data     <SEC-DOCUMENT>0001018724-22-000005.txt : 20220...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-202...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2021...
# docs_10k_clean  \n10-k\n1\namzn-20211231.htm\n10-k\n\n\n\namzn...
#
#                                                        2021-02-03  \
# filing_data     <SEC-DOCUMENT>0001018724-21-000004.txt : 20210...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-202...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2020...
# docs_10k_clean  \n10-k\n1\namzn-20201231.htm\n10-k\n\n\n\namzn...
#
#                                                        2020-01-31  \
# filing_data     <SEC-DOCUMENT>0001018724-20-000004.txt : 20200...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2019...
# docs_10k_clean  \n10-k\n1\namzn-20191231x10k.htm\n10-k\n\n\n\n...
#
#                                                        2019-02-01  \
# filing_data     <SEC-DOCUMENT>0001018724-19-000004.txt : 20190...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2018...
# docs_10k_clean  \n10-k\n1\namzn-20181231x10k.htm\n10-k\n\n\n\n...
#
#                                                        2018-02-02  \
# filing_data     <SEC-DOCUMENT>0001018724-18-000005.txt : 20180...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2017...
# docs_10k_clean  \n10-k\n1\namzn-20171231x10k.htm\n10-k\n\n\n\n...
#
#                                                        2017-02-10  \
# filing_data     <SEC-DOCUMENT>0001018724-17-000011.txt : 20170...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2016...
# docs_10k_clean  \n10-k\n1\namzn-20161231x10k.htm\nform 10-k\n\...
#
#                                                        2016-01-29  \
# filing_data     <SEC-DOCUMENT>0001018724-16-000172.txt : 20160...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2015...
# docs_10k_clean  \n10-k\n1\namzn-20151231x10k.htm\nform 10-k\n\...
#
#                                                        2015-01-30  \
# filing_data     <SEC-DOCUMENT>0001018724-15-000006.txt : 20150...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2014...
# docs_10k_clean  \n10-k\n1\namzn-20141231x10k.htm\nform 10-k\n\...
#
#                                                        2014-01-31  \
# filing_data     <SEC-DOCUMENT>0001018724-14-000006.txt : 20140...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-201...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>amzn-2013...
# docs_10k_clean  \n10-k\n1\namzn-20131231x10k.htm\nform 10-k\n\...
#
#                                                        2013-01-30  ...  \
# filing_data     <SEC-DOCUMENT>0001193125-13-028520.txt : 20130...  ...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d445434d...  ...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d445434d1...  ...
# docs_10k_clean  \n10-k\n1\nd445434d10k.htm\nform 10-k\n\n\nfor...  ...
#
#                                                        2010-01-29  \
# filing_data     -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
# docs_10k_clean  \n10-k\n1\nd10k.htm\nform 10-k\n\n\nform 10-k\...
#
#                                                        2009-01-30  \
# filing_data     -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
# docs_10k_clean  \n10-k\n1\nd10k.htm\nform 10-k\n\n\nform 10-k\...
#
#                                                        2008-02-11  \
# filing_data     -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
# docs_10k_clean  \n10-k\n1\nd10k.htm\nform 10-k\n\n\nform 10-k\...
#
#                                                        2007-02-16  \
# filing_data     -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
# docs_10k_clean  \n10-k\n1\nd10k.htm\nform 10-k\n\n\nform 10-k\...
#
#                                                        2006-02-17  \
# filing_data     -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
# docs_10k_clean  \n10-k\n1\nd10k.htm\nannual report\n\n\nannual...
#
#                                                        2005-03-11  \
# filing_data     -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
# docs_10k_clean  \n10-k\n1\nd10k.htm\nannual report for the fis...
#
#                                                        2004-02-25  \
# filing_data     -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>d10k.htm\...
# docs_10k_clean  \n10-k\n1\nd10k.htm\nform 10-k for the fiscal ...
#
#                                                        2003-02-19  \
# filing_data     -----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc...
# documents       [\n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>v87419or...
# docs_10k        \n<TYPE>10-K\n<SEQUENCE>1\n<FILENAME>v87419ore...
# docs_10k_clean  \n10-k\n1\nv87419ore10vk.htm\nform 10-k\n\n\n\...
#
#                                                        2000-03-29  \
# filing_data     <?xml version="1.0" encoding="UTF-8"?>\n<Error...
# documents                                                      []
# docs_10k                                                      NaN
# docs_10k_clean                                                NaN
#
#                                                        1999-03-05
# filing_data     <?xml version="1.0" encoding="UTF-8"?>\n<Error...
# documents                                                      []
# docs_10k                                                      NaN
# docs_10k_clean                                                NaN
#
# [4 rows x 22 columns]

# %%
dates = df5.columns

# %%
df5 = df5.T
df6=pd.DataFrame()
df6["raw_data"]=df5["docs_10k_clean"]

# %%
df6.head()
# Out:
#                                                      raw_data
# 2022-02-04  \n10-k\n1\namzn-20211231.htm\n10-k\n\n\n\namzn...
# 2021-02-03  \n10-k\n1\namzn-20201231.htm\n10-k\n\n\n\namzn...
# 2020-01-31  \n10-k\n1\namzn-20191231x10k.htm\n10-k\n\n\n\n...
# 2019-02-01  \n10-k\n1\namzn-20181231x10k.htm\n10-k\n\n\n\n...
# 2018-02-02  \n10-k\n1\namzn-20171231x10k.htm\n10-k\n\n\n\n...

# %%
df6["raw_data"] = df6["raw_data"].apply(lambda x: str(x))

df6=preprocess_data.process(df6)
df6["final_cleaned"] = df6["cleaned_no_stop_punc_data"].apply(lambda x: ' '.join(s for s in x.split() if not any(c.isdigit() for c in s)))
df6.head()
# Out:
#                                                      raw_data  \
# 2022-02-04  \n10-k\n1\namzn-20211231.htm\n10-k\n\n\n\namzn...
# 2021-02-03  \n10-k\n1\namzn-20201231.htm\n10-k\n\n\n\namzn...
# 2020-01-31  \n10-k\n1\namzn-20191231x10k.htm\n10-k\n\n\n\n...
# 2019-02-01  \n10-k\n1\namzn-20181231x10k.htm\n10-k\n\n\n\n...
# 2018-02-02  \n10-k\n1\namzn-20171231x10k.htm\n10-k\n\n\n\n...
#
#                                                  cleaned_data  \
# 2022-02-04  10-k amzn-20211231.htm 10-k of contentsunited ...
# 2021-02-03  10-k amzn-20201231.htm 10-k amzn-20201231false...
# 2020-01-31  10-k amzn-20191231x10k.htm 10-k document 0.5p1...
# 2019-02-01  10-k amzn-20181231x10k.htm 10-k document table...
# 2018-02-02  10-k amzn-20171231x10k.htm 10-k document unite...
#
#                                     cleaned_no_stop_punc_data  \
# 2022-02-04  10 k amzn 20211231 htm 10 k of contentsunited ...
# 2021-02-03  10 k amzn 20201231 htm 10 k amzn 20201231false...
# 2020-01-31  10 k amzn 20191231x10k htm 10 k document 0 5p1...
# 2019-02-01  10 k amzn 20181231x10k htm 10 k document table...
# 2018-02-02  10 k amzn 20171231x10k htm 10 k document unite...
#
#                                                 final_cleaned
# 2022-02-04  k amzn htm k of contentsunited statessecuritie...
# 2021-02-03  k amzn htm k amzn gaap accruedliabilitiescurre...
# 2020-01-31  k amzn htm k document us gaap productmember us...
# 2019-02-01  k amzn htm k document table of contents united...
# 2018-02-02  k amzn htm k document united statessecurities ...

# %%
df6.shape
# Out:
# (22, 4)

# %%
data=pd.DataFrame()
data["dates"]=dates
data['data'] = df6['final_cleaned'].values

# %%
data.head()
# Out:
#         dates                                               data
# 0  2022-02-04  k amzn htm k of contentsunited statessecuritie...
# 1  2021-02-03  k amzn htm k amzn gaap accruedliabilitiescurre...
# 2  2020-01-31  k amzn htm k document us gaap productmember us...
# 3  2019-02-01  k amzn htm k document table of contents united...
# 4  2018-02-02  k amzn htm k document united statessecurities ...

# %%
data.to_csv('output/sec_10k.csv', index=False)
